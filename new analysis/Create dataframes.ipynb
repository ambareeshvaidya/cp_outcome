# %%
import pandas as pd
import numpy as np

# %%
# cuts-off dataframes

df_0_2 = pd.read_csv('result_0_2.csv', nrows = 426)
df_0_4 = pd.read_csv('result_0_4.csv', nrows = 426)
df_0_8 = pd.read_csv('result_0_8.csv', nrows = 426)
df_0_16 = pd.read_csv('result_0_16.csv', nrows = 426)
df_0_32 = pd.read_csv('result_0_32.csv', nrows = 426)
df_0_32
# Out:
#                             NAME    INITIAL LP  FIRST ROUND CUT  \
# 0                 10teams.mps.gz  2.000000e+01                0
# 1                   22433.mps.gz  2.124053e+04                0
# 2                   23588.mps.gz  7.649866e+03                0
# 3         30_70_45_05_100.mps.gz -5.336000e+03                0
# 4        30_70_45_095_100.mps.gz -6.132000e+03                0
# ..                           ...           ...              ...
# 421             unitcal_7.mps.gz  1.028415e+06                0
# 422   var-smallemery-m6j6.mps.gz -1.697219e+03                0
# 423              wachplan.mps.gz -2.400000e+01                0
# 424      2club200v15p5scn.mps.gz -2.000000e+02                0
# 425  academictimetablebig.mps.gz  4.040000e+02                0
#
#      ROUND OF CUTS  OBJECTIVE VALUE ROOT NODE  BEST SOLUTION  SOLUTION TIME  \
# 0                0               9.170000e+02   9.240000e+02      12.023708
# ...

# %%
df_nocuts = pd.concat([df_0_2,df_0_4,df_0_8,df_0_16,df_0_32])
df_nocuts = df_nocuts.sort_values(by='NAME', ascending=True)

# %%
df_nocuts.rename(columns={'INITIAL LP TIME':'PRESOLVING TIME W/O CUTS'}, inplace = True)
df_nocuts = df_nocuts.drop(['PRESOLVING TIME'], axis = 1)
df_nocuts.to_csv('df_nocuts.csv')

# %%
# cuts-on data

df_1_2 = pd.read_csv('result_1_2.csv', nrows = 426)
df_1_4 = pd.read_csv('result_1_4.csv', nrows = 426)
df_1_8 = pd.read_csv('result_1_8.csv', nrows = 426)
df_1_16 = pd.read_csv('result_1_16.csv', nrows = 426)
df_1_32 = pd.read_csv('result_1_32.csv', nrows = 426)
df_1_32
# Out:
#                            NAME    INITIAL LP  FIRST ROUND CUT  ROUND OF CUTS  \
# 0                10teams.mps.gz  2.000000e+01     9.170000e+02             13
# 1                  22433.mps.gz  2.124053e+04     2.127800e+04             58
# 2                  23588.mps.gz  7.649866e+03     7.660000e+03             34
# 3        30_70_45_05_100.mps.gz -5.336000e+03     8.500000e+00             13
# 4       30_70_45_095_100.mps.gz -6.132000e+03     3.000000e+00             12
# ..                          ...           ...              ...            ...
# 421          uct-subprob.mps.gz -2.000000e+00     2.440000e+02             52
# 422                 umts.mps.gz  1.460426e+06     2.912957e+07             30
# 423            unitcal_7.mps.gz  1.028415e+06     1.946934e+07             86
# 424  var-smallemery-m6j6.mps.gz -1.697219e+03    -1.549250e+02              1
# 425             wachplan.mps.gz -2.400000e+01    -9.000000e+00             12
#
# ...

# %%
df_cuts = pd.concat([df_1_2,df_1_4,df_1_8,df_1_16,df_1_32])
df_cuts = df_cuts.sort_values(by='NAME', ascending=True)

# %%
df_cuts.rename(columns={'INITIAL LP TIME':'PRESOLVING TIME W/ CUTS'}, inplace = True)
df_cuts = df_cuts.drop(['PRESOLVING TIME'], axis = 1)
df_cuts.to_csv('df_cuts.csv')

# %%
df_cuts.loc[df_cuts['SOLUTION TIME']<df_cuts['PRESOLVING TIME']]
# Out:
#                          NAME  INITIAL LP  FIRST ROUND CUT  ROUND OF CUTS  \
# 195  neos-3116779-oban.mps.gz         0.0              0.0              0
# 195  neos-3116779-oban.mps.gz         0.0              0.0              0
# 195  neos-3116779-oban.mps.gz         0.0              0.0              0
# 195  neos-3116779-oban.mps.gz         0.0              0.0              0
# 195  neos-3116779-oban.mps.gz         0.0              0.0              0
#
#      OBJECTIVE VALUE ROOT NODE  BEST SOLUTION  SOLUTION TIME  PRESOLVING TIME  \
# 195                        0.0            0.0       0.035124         0.045244
# 195                        0.0            0.0       0.035209         0.047037
# 195                        0.0            0.0       0.042193         0.055560
# 195                        0.0            0.0       0.043192         0.055710
# 195                        0.0            0.0       0.043142         0.055727
#
# ...

# %%
df = df_1_2[~df_1_2['NAME'].isin(df_0_8['NAME'])]
df
# Out:
#                            NAME  INITIAL LP  FIRST ROUND CUT  ROUND OF CUTS  \
# 242          neos-498623.mps.gz    -6623.60        16.000000             29
# 247  neos-5079731-flyers.mps.gz     2004.00      2011.307692             36
# 291          neos-911970.mps.gz       23.26        23.260000            129
#
#      OBJECTIVE VALUE ROOT NODE  BEST SOLUTION  SOLUTION TIME  PRESOLVING TIME  \
# 242                  16.600000          16.60      31.514312         1.351038
# 247                2330.000000        2440.00    2436.871578         5.276477
# 291                  52.492963          54.76      66.251777         0.096792
#
#      BEST PRIMAL BOUND  GAP  ...  No. OF CUTS APPLIED  \
# 242              16.60  0.0  ...                  179
# 247            2440.00  0.0  ...                17097
# 291              54.76  0.0  ...                 9257
#
#      No. OF CUTS PRESENT IN LP AT THE END  No. OF NODES  INITIAL LP TIME  \
# ...
